# %%
# !pip install virtualenv
# !virtualenv /content/drive/MyDrive/mujoco_pg_env
# !source /content/drive/MyDrive/mujoco_pg_env/bin/activate
# !git clone -b feat/training https://github.com/makotovnjp/mujoco_playground.git
# !pip install playground
# !cd /home/sandbox/Work/mujoco_playground && pip install -e ".[all]"
# !pip install --upgrade --force-reinstall "jax[cuda12]"
# Out:
# Requirement already satisfied: playground in ./venv/lib/python3.12/site-packages (0.0.5)
# Requirement already satisfied: brax>=0.12.1 in ./venv/lib/python3.12/site-packages (from playground) (0.13.0)
# Requirement already satisfied: etils in ./venv/lib/python3.12/site-packages (from playground) (1.13.0)
# Requirement already satisfied: flax in ./venv/lib/python3.12/site-packages (from playground) (0.12.0)
# Requirement already satisfied: jax in ./venv/lib/python3.12/site-packages (from playground) (0.7.2)
# Requirement already satisfied: lxml in ./venv/lib/python3.12/site-packages (from playground) (6.0.2)
# Requirement already satisfied: ml-collections in ./venv/lib/python3.12/site-packages (from playground) (1.1.0)
# Requirement already satisfied: mujoco-mjx>=3.2.7 in ./venv/lib/python3.12/site-packages (from playground) (3.3.6)
# Requirement already satisfied: mujoco>=3.2.7 in ./venv/lib/python3.12/site-packages (from playground) (3.3.6)
# Requirement already satisfied: tqdm in ./venv/lib/python3.12/site-packages (from playground) (4.67.1)
# Requirement already satisfied: absl-py in ./venv/lib/python3.12/site-packages (from brax>=0.12.1->playground) (2.3.1)
# Requirement already satisfied: flask in ./venv/lib/python3.12/site-packages (from brax>=0.12.1->playground) (3.1.2)
# Requirement already satisfied: flask-cors in ./venv/lib/python3.12/site-packages (from brax>=0.12.1->playground) (6.0.1)
# Requirement already satisfied: jaxlib>=0.4.6 in ./venv/lib/python3.12/site-packages (from brax>=0.12.1->playground) (0.7.2)
# Requirement already satisfied: jaxopt in ./venv/lib/python3.12/site-packages (from brax>=0.12.1->playground) (0.8.5)
# Requirement already satisfied: jinja2 in ./venv/lib/python3.12/site-packages (from brax>=0.12.1->playground) (3.1.6)
# Requirement already satisfied: numpy in ./venv/lib/python3.12/site-packages (from brax>=0.12.1->playground) (2.3.3)
# Requirement already satisfied: optax in ./venv/lib/python3.12/site-packages (from brax>=0.12.1->playground) (0.2.6)
# Requirement already satisfied: orbax-checkpoint>=0.11.22 in ./venv/lib/python3.12/site-packages (from brax>=0.12.1->playground) (0.11.25)
# Requirement already satisfied: pillow in ./venv/lib/python3.12/site-packages (from brax>=0.12.1->playground) (11.3.0)
# Requirement already satisfied: scipy in ./venv/lib/python3.12/site-packages (from brax>=0.12.1->playground) (1.16.2)
# Requirement already satisfied: tensorboardx in ./venv/lib/python3.12/site-packages (from brax>=0.12.1->playground) (2.6.4)
# Requirement already satisfied: trimesh in ./venv/lib/python3.12/site-packages (from brax>=0.12.1->playground) (4.8.3)
# Requirement already satisfied: typing-extensions in ./venv/lib/python3.12/site-packages (from brax>=0.12.1->playground) (4.15.0)
# Requirement already satisfied: ml_dtypes>=0.5.0 in ./venv/lib/python3.12/site-packages (from jax->playground) (0.5.3)
# Requirement already satisfied: opt_einsum in ./venv/lib/python3.12/site-packages (from jax->playground) (3.4.0)
# Requirement already satisfied: glfw in ./venv/lib/python3.12/site-packages (from mujoco>=3.2.7->playground) (2.10.0)
# Requirement already satisfied: pyopengl in ./venv/lib/python3.12/site-packages (from mujoco>=3.2.7->playground) (3.1.10)
# Requirement already satisfied: msgpack in ./venv/lib/python3.12/site-packages (from flax->playground) (1.1.1)
# Requirement already satisfied: tensorstore in ./venv/lib/python3.12/site-packages (from flax->playground) (0.1.77)
# Requirement already satisfied: rich>=11.1 in ./venv/lib/python3.12/site-packages (from flax->playground) (14.1.0)
# Requirement already satisfied: PyYAML>=5.4.1 in ./venv/lib/python3.12/site-packages (from flax->playground) (6.0.3)
# Requirement already satisfied: treescope>=0.1.7 in ./venv/lib/python3.12/site-packages (from flax->playground) (0.1.10)
# Requirement already satisfied: nest_asyncio in ./venv/lib/python3.12/site-packages (from orbax-checkpoint>=0.11.22->brax>=0.12.1->playground) (1.6.0)
# Requirement already satisfied: aiofiles in ./venv/lib/python3.12/site-packages (from orbax-checkpoint>=0.11.22->brax>=0.12.1->playground) (24.1.0)
# Requirement already satisfied: protobuf in ./venv/lib/python3.12/site-packages (from orbax-checkpoint>=0.11.22->brax>=0.12.1->playground) (6.32.1)
# Requirement already satisfied: humanize in ./venv/lib/python3.12/site-packages (from orbax-checkpoint>=0.11.22->brax>=0.12.1->playground) (4.13.0)
# Requirement already satisfied: simplejson>=3.16.0 in ./venv/lib/python3.12/site-packages (from orbax-checkpoint>=0.11.22->brax>=0.12.1->playground) (3.20.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in ./venv/lib/python3.12/site-packages (from rich>=11.1->flax->playground) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./venv/lib/python3.12/site-packages (from rich>=11.1->flax->playground) (2.19.2)
# Requirement already satisfied: fsspec in ./venv/lib/python3.12/site-packages (from etils[epath]->mujoco>=3.2.7->playground) (2025.9.0)
# Requirement already satisfied: importlib_resources in ./venv/lib/python3.12/site-packages (from etils[epath]->mujoco>=3.2.7->playground) (6.5.2)
# Requirement already satisfied: zipp in ./venv/lib/python3.12/site-packages (from etils[epath]->mujoco>=3.2.7->playground) (3.23.0)
# Requirement already satisfied: blinker>=1.9.0 in ./venv/lib/python3.12/site-packages (from flask->brax>=0.12.1->playground) (1.9.0)
# Requirement already satisfied: click>=8.1.3 in ./venv/lib/python3.12/site-packages (from flask->brax>=0.12.1->playground) (8.3.0)
# Requirement already satisfied: itsdangerous>=2.2.0 in ./venv/lib/python3.12/site-packages (from flask->brax>=0.12.1->playground) (2.2.0)
# Requirement already satisfied: markupsafe>=2.1.1 in ./venv/lib/python3.12/site-packages (from flask->brax>=0.12.1->playground) (3.0.3)
# Requirement already satisfied: werkzeug>=3.1.0 in ./venv/lib/python3.12/site-packages (from flask->brax>=0.12.1->playground) (3.1.3)
# Requirement already satisfied: chex>=0.1.87 in ./venv/lib/python3.12/site-packages (from optax->brax>=0.12.1->playground) (0.1.91)
# Requirement already satisfied: packaging in ./venv/lib/python3.12/site-packages (from tensorboardx->brax>=0.12.1->playground) (25.0)
# Requirement already satisfied: toolz>=1.0.0 in ./venv/lib/python3.12/site-packages (from chex>=0.1.87->optax->brax>=0.12.1->playground) (1.0.0)
# Requirement already satisfied: mdurl~=0.1 in ./venv/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=11.1->flax->playground) (0.1.2)
#
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip
# Obtaining file:///home/sandbox/Work/mujoco_playground
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Installing backend dependencies ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: brax>=0.12.1 in ./learning/notebooks/venv/lib/python3.12/site-packages (from playground==0.0.5) (0.13.0)
# Requirement already satisfied: etils in ./learning/notebooks/venv/lib/python3.12/site-packages (from playground==0.0.5) (1.13.0)
# Requirement already satisfied: flax in ./learning/notebooks/venv/lib/python3.12/site-packages (from playground==0.0.5) (0.12.0)
# Requirement already satisfied: jax in ./learning/notebooks/venv/lib/python3.12/site-packages (from playground==0.0.5) (0.7.2)
# Requirement already satisfied: lxml in ./learning/notebooks/venv/lib/python3.12/site-packages (from playground==0.0.5) (6.0.2)
# Requirement already satisfied: ml-collections in ./learning/notebooks/venv/lib/python3.12/site-packages (from playground==0.0.5) (1.1.0)
# Requirement already satisfied: mujoco-mjx>=3.2.7 in ./learning/notebooks/venv/lib/python3.12/site-packages (from playground==0.0.5) (3.3.6)
# Requirement already satisfied: mujoco>=3.2.7 in ./learning/notebooks/venv/lib/python3.12/site-packages (from playground==0.0.5) (3.3.6)
# Requirement already satisfied: tqdm in ./learning/notebooks/venv/lib/python3.12/site-packages (from playground==0.0.5) (4.67.1)
# Requirement already satisfied: absl-py in ./learning/notebooks/venv/lib/python3.12/site-packages (from playground==0.0.5) (2.3.1)
# Requirement already satisfied: dm-control in ./learning/notebooks/venv/lib/python3.12/site-packages (from playground==0.0.5) (1.0.34)
# Requirement already satisfied: jupyter in ./learning/notebooks/venv/lib/python3.12/site-packages (from playground==0.0.5) (1.1.1)
# Requirement already satisfied: matplotlib in ./learning/notebooks/venv/lib/python3.12/site-packages (from playground==0.0.5) (3.10.6)
# Requirement already satisfied: mediapy in ./learning/notebooks/venv/lib/python3.12/site-packages (from playground==0.0.5) (1.2.4)
# Requirement already satisfied: mypy in ./learning/notebooks/venv/lib/python3.12/site-packages (from playground==0.0.5) (1.18.2)
# Requirement already satisfied: pre-commit in ./learning/notebooks/venv/lib/python3.12/site-packages (from playground==0.0.5) (4.3.0)
# Requirement already satisfied: pyink in ./learning/notebooks/venv/lib/python3.12/site-packages (from playground==0.0.5) (24.10.1)
# Requirement already satisfied: pylint in ./learning/notebooks/venv/lib/python3.12/site-packages (from playground==0.0.5) (3.3.8)
# Requirement already satisfied: pytest in ./learning/notebooks/venv/lib/python3.12/site-packages (from playground==0.0.5) (8.4.2)
# Requirement already satisfied: pytest-xdist in ./learning/notebooks/venv/lib/python3.12/site-packages (from playground==0.0.5) (3.8.0)
# Requirement already satisfied: pytype in ./learning/notebooks/venv/lib/python3.12/site-packages (from playground==0.0.5) (2024.10.11)
# Requirement already satisfied: ruff in ./learning/notebooks/venv/lib/python3.12/site-packages (from playground==0.0.5) (0.13.3)
# Requirement already satisfied: wandb in ./learning/notebooks/venv/lib/python3.12/site-packages (from playground==0.0.5) (0.22.1)
# Requirement already satisfied: flask in ./learning/notebooks/venv/lib/python3.12/site-packages (from brax>=0.12.1->playground==0.0.5) (3.1.2)
# Requirement already satisfied: flask-cors in ./learning/notebooks/venv/lib/python3.12/site-packages (from brax>=0.12.1->playground==0.0.5) (6.0.1)
# Requirement already satisfied: jaxlib>=0.4.6 in ./learning/notebooks/venv/lib/python3.12/site-packages (from brax>=0.12.1->playground==0.0.5) (0.7.2)
# Requirement already satisfied: jaxopt in ./learning/notebooks/venv/lib/python3.12/site-packages (from brax>=0.12.1->playground==0.0.5) (0.8.5)
# Requirement already satisfied: jinja2 in ./learning/notebooks/venv/lib/python3.12/site-packages (from brax>=0.12.1->playground==0.0.5) (3.1.6)
# Requirement already satisfied: numpy in ./learning/notebooks/venv/lib/python3.12/site-packages (from brax>=0.12.1->playground==0.0.5) (2.3.3)
# Requirement already satisfied: optax in ./learning/notebooks/venv/lib/python3.12/site-packages (from brax>=0.12.1->playground==0.0.5) (0.2.6)
# Requirement already satisfied: orbax-checkpoint>=0.11.22 in ./learning/notebooks/venv/lib/python3.12/site-packages (from brax>=0.12.1->playground==0.0.5) (0.11.25)
# Requirement already satisfied: pillow in ./learning/notebooks/venv/lib/python3.12/site-packages (from brax>=0.12.1->playground==0.0.5) (11.3.0)
# Requirement already satisfied: scipy in ./learning/notebooks/venv/lib/python3.12/site-packages (from brax>=0.12.1->playground==0.0.5) (1.16.2)
# Requirement already satisfied: tensorboardx in ./learning/notebooks/venv/lib/python3.12/site-packages (from brax>=0.12.1->playground==0.0.5) (2.6.4)
# Requirement already satisfied: trimesh in ./learning/notebooks/venv/lib/python3.12/site-packages (from brax>=0.12.1->playground==0.0.5) (4.8.3)
# Requirement already satisfied: typing-extensions in ./learning/notebooks/venv/lib/python3.12/site-packages (from brax>=0.12.1->playground==0.0.5) (4.15.0)
# Requirement already satisfied: ml_dtypes>=0.5.0 in ./learning/notebooks/venv/lib/python3.12/site-packages (from jax->playground==0.0.5) (0.5.3)
# Requirement already satisfied: opt_einsum in ./learning/notebooks/venv/lib/python3.12/site-packages (from jax->playground==0.0.5) (3.4.0)
# Requirement already satisfied: glfw in ./learning/notebooks/venv/lib/python3.12/site-packages (from mujoco>=3.2.7->playground==0.0.5) (2.10.0)
# Requirement already satisfied: pyopengl in ./learning/notebooks/venv/lib/python3.12/site-packages (from mujoco>=3.2.7->playground==0.0.5) (3.1.10)
# Requirement already satisfied: dm-env in ./learning/notebooks/venv/lib/python3.12/site-packages (from dm-control->playground==0.0.5) (1.6)
# Requirement already satisfied: dm-tree!=0.1.2 in ./learning/notebooks/venv/lib/python3.12/site-packages (from dm-control->playground==0.0.5) (0.1.9)
# Requirement already satisfied: labmaze in ./learning/notebooks/venv/lib/python3.12/site-packages (from dm-control->playground==0.0.5) (1.0.6)
# Requirement already satisfied: protobuf>=3.19.4 in ./learning/notebooks/venv/lib/python3.12/site-packages (from dm-control->playground==0.0.5) (6.32.1)
# Requirement already satisfied: pyparsing>=3.0.0 in ./learning/notebooks/venv/lib/python3.12/site-packages (from dm-control->playground==0.0.5) (3.2.5)
# Requirement already satisfied: requests in ./learning/notebooks/venv/lib/python3.12/site-packages (from dm-control->playground==0.0.5) (2.32.5)
# Requirement already satisfied: setuptools!=50.0.0 in ./learning/notebooks/venv/lib/python3.12/site-packages (from dm-control->playground==0.0.5) (80.9.0)
# Requirement already satisfied: msgpack in ./learning/notebooks/venv/lib/python3.12/site-packages (from flax->playground==0.0.5) (1.1.1)
# Requirement already satisfied: tensorstore in ./learning/notebooks/venv/lib/python3.12/site-packages (from flax->playground==0.0.5) (0.1.77)
# Requirement already satisfied: rich>=11.1 in ./learning/notebooks/venv/lib/python3.12/site-packages (from flax->playground==0.0.5) (14.1.0)
# Requirement already satisfied: PyYAML>=5.4.1 in ./learning/notebooks/venv/lib/python3.12/site-packages (from flax->playground==0.0.5) (6.0.3)
# Requirement already satisfied: treescope>=0.1.7 in ./learning/notebooks/venv/lib/python3.12/site-packages (from flax->playground==0.0.5) (0.1.10)
# Requirement already satisfied: notebook in ./learning/notebooks/venv/lib/python3.12/site-packages (from jupyter->playground==0.0.5) (7.4.7)
# Requirement already satisfied: jupyter-console in ./learning/notebooks/venv/lib/python3.12/site-packages (from jupyter->playground==0.0.5) (6.6.3)
# Requirement already satisfied: nbconvert in ./learning/notebooks/venv/lib/python3.12/site-packages (from jupyter->playground==0.0.5) (7.16.6)
# Requirement already satisfied: ipykernel in ./learning/notebooks/venv/lib/python3.12/site-packages (from jupyter->playground==0.0.5) (6.30.1)
# Requirement already satisfied: ipywidgets in ./learning/notebooks/venv/lib/python3.12/site-packages (from jupyter->playground==0.0.5) (8.1.7)
# Requirement already satisfied: jupyterlab in ./learning/notebooks/venv/lib/python3.12/site-packages (from jupyter->playground==0.0.5) (4.4.9)
# Requirement already satisfied: contourpy>=1.0.1 in ./learning/notebooks/venv/lib/python3.12/site-packages (from matplotlib->playground==0.0.5) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in ./learning/notebooks/venv/lib/python3.12/site-packages (from matplotlib->playground==0.0.5) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./learning/notebooks/venv/lib/python3.12/site-packages (from matplotlib->playground==0.0.5) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./learning/notebooks/venv/lib/python3.12/site-packages (from matplotlib->playground==0.0.5) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in ./learning/notebooks/venv/lib/python3.12/site-packages (from matplotlib->playground==0.0.5) (25.0)
# Requirement already satisfied: python-dateutil>=2.7 in ./learning/notebooks/venv/lib/python3.12/site-packages (from matplotlib->playground==0.0.5) (2.9.0.post0)
# Requirement already satisfied: ipython in ./learning/notebooks/venv/lib/python3.12/site-packages (from mediapy->playground==0.0.5) (9.6.0)
# Requirement already satisfied: mypy_extensions>=1.0.0 in ./learning/notebooks/venv/lib/python3.12/site-packages (from mypy->playground==0.0.5) (1.1.0)
# Requirement already satisfied: pathspec>=0.9.0 in ./learning/notebooks/venv/lib/python3.12/site-packages (from mypy->playground==0.0.5) (0.12.1)
# Requirement already satisfied: cfgv>=2.0.0 in ./learning/notebooks/venv/lib/python3.12/site-packages (from pre-commit->playground==0.0.5) (3.4.0)
# Requirement already satisfied: identify>=1.0.0 in ./learning/notebooks/venv/lib/python3.12/site-packages (from pre-commit->playground==0.0.5) (2.6.15)
# Requirement already satisfied: nodeenv>=0.11.1 in ./learning/notebooks/venv/lib/python3.12/site-packages (from pre-commit->playground==0.0.5) (1.9.1)
# Requirement already satisfied: virtualenv>=20.10.0 in ./learning/notebooks/venv/lib/python3.12/site-packages (from pre-commit->playground==0.0.5) (20.34.0)
# Requirement already satisfied: black==24.10.0 in ./learning/notebooks/venv/lib/python3.12/site-packages (from pyink->playground==0.0.5) (24.10.0)
# Requirement already satisfied: click>=8.0.0 in ./learning/notebooks/venv/lib/python3.12/site-packages (from pyink->playground==0.0.5) (8.3.0)
# Requirement already satisfied: platformdirs>=2 in ./learning/notebooks/venv/lib/python3.12/site-packages (from pyink->playground==0.0.5) (4.4.0)
# Requirement already satisfied: astroid<=3.4.0.dev0,>=3.3.8 in ./learning/notebooks/venv/lib/python3.12/site-packages (from pylint->playground==0.0.5) (3.3.11)
# Requirement already satisfied: dill>=0.3.6 in ./learning/notebooks/venv/lib/python3.12/site-packages (from pylint->playground==0.0.5) (0.4.0)
# Requirement already satisfied: isort!=5.13,<7,>=4.2.5 in ./learning/notebooks/venv/lib/python3.12/site-packages (from pylint->playground==0.0.5) (6.1.0)
# Requirement already satisfied: mccabe<0.8,>=0.6 in ./learning/notebooks/venv/lib/python3.12/site-packages (from pylint->playground==0.0.5) (0.7.0)
# Requirement already satisfied: tomlkit>=0.10.1 in ./learning/notebooks/venv/lib/python3.12/site-packages (from pylint->playground==0.0.5) (0.13.3)
# Requirement already satisfied: iniconfig>=1 in ./learning/notebooks/venv/lib/python3.12/site-packages (from pytest->playground==0.0.5) (2.1.0)
# Requirement already satisfied: pluggy<2,>=1.5 in ./learning/notebooks/venv/lib/python3.12/site-packages (from pytest->playground==0.0.5) (1.6.0)
# Requirement already satisfied: pygments>=2.7.2 in ./learning/notebooks/venv/lib/python3.12/site-packages (from pytest->playground==0.0.5) (2.19.2)
# Requirement already satisfied: execnet>=2.1 in ./learning/notebooks/venv/lib/python3.12/site-packages (from pytest-xdist->playground==0.0.5) (2.1.1)
# Requirement already satisfied: attrs>=21.4.0 in ./learning/notebooks/venv/lib/python3.12/site-packages (from pytype->playground==0.0.5) (25.3.0)
# Requirement already satisfied: importlab>=0.8 in ./learning/notebooks/venv/lib/python3.12/site-packages (from pytype->playground==0.0.5) (0.8.1)
# Requirement already satisfied: immutabledict>=4.1.0 in ./learning/notebooks/venv/lib/python3.12/site-packages (from pytype->playground==0.0.5) (4.2.1)
# Requirement already satisfied: libcst>=1.0.1 in ./learning/notebooks/venv/lib/python3.12/site-packages (from pytype->playground==0.0.5) (1.8.5)
# Requirement already satisfied: msgspec>=0.18.6 in ./learning/notebooks/venv/lib/python3.12/site-packages (from pytype->playground==0.0.5) (0.19.0)
# Requirement already satisfied: networkx>=2.8 in ./learning/notebooks/venv/lib/python3.12/site-packages (from pytype->playground==0.0.5) (3.5)
# Requirement already satisfied: ninja>=1.10.0.post2 in ./learning/notebooks/venv/lib/python3.12/site-packages (from pytype->playground==0.0.5) (1.13.0)
# Requirement already satisfied: pycnite>=2024.07.31 in ./learning/notebooks/venv/lib/python3.12/site-packages (from pytype->playground==0.0.5) (2024.7.31)
# Requirement already satisfied: pydot>=1.4.2 in ./learning/notebooks/venv/lib/python3.12/site-packages (from pytype->playground==0.0.5) (4.0.1)
# Requirement already satisfied: tabulate>=0.8.10 in ./learning/notebooks/venv/lib/python3.12/site-packages (from pytype->playground==0.0.5) (0.9.0)
# Requirement already satisfied: toml>=0.10.2 in ./learning/notebooks/venv/lib/python3.12/site-packages (from pytype->playground==0.0.5) (0.10.2)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in ./learning/notebooks/venv/lib/python3.12/site-packages (from wandb->playground==0.0.5) (3.1.45)
# Requirement already satisfied: pydantic<3 in ./learning/notebooks/venv/lib/python3.12/site-packages (from wandb->playground==0.0.5) (2.11.9)
# Requirement already satisfied: sentry-sdk>=2.0.0 in ./learning/notebooks/venv/lib/python3.12/site-packages (from wandb->playground==0.0.5) (2.39.0)
# Requirement already satisfied: wrapt>=1.11.2 in ./learning/notebooks/venv/lib/python3.12/site-packages (from dm-tree!=0.1.2->dm-control->playground==0.0.5) (1.17.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in ./learning/notebooks/venv/lib/python3.12/site-packages (from gitpython!=3.1.29,>=1.0.0->wandb->playground==0.0.5) (4.0.12)
# Requirement already satisfied: MarkupSafe>=2.0 in ./learning/notebooks/venv/lib/python3.12/site-packages (from jinja2->brax>=0.12.1->playground==0.0.5) (3.0.3)
# Requirement already satisfied: nest_asyncio in ./learning/notebooks/venv/lib/python3.12/site-packages (from orbax-checkpoint>=0.11.22->brax>=0.12.1->playground==0.0.5) (1.6.0)
# Requirement already satisfied: aiofiles in ./learning/notebooks/venv/lib/python3.12/site-packages (from orbax-checkpoint>=0.11.22->brax>=0.12.1->playground==0.0.5) (24.1.0)
# Requirement already satisfied: humanize in ./learning/notebooks/venv/lib/python3.12/site-packages (from orbax-checkpoint>=0.11.22->brax>=0.12.1->playground==0.0.5) (4.13.0)
# Requirement already satisfied: simplejson>=3.16.0 in ./learning/notebooks/venv/lib/python3.12/site-packages (from orbax-checkpoint>=0.11.22->brax>=0.12.1->playground==0.0.5) (3.20.2)
# Requirement already satisfied: annotated-types>=0.6.0 in ./learning/notebooks/venv/lib/python3.12/site-packages (from pydantic<3->wandb->playground==0.0.5) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in ./learning/notebooks/venv/lib/python3.12/site-packages (from pydantic<3->wandb->playground==0.0.5) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in ./learning/notebooks/venv/lib/python3.12/site-packages (from pydantic<3->wandb->playground==0.0.5) (0.4.2)
# Requirement already satisfied: six>=1.5 in ./learning/notebooks/venv/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib->playground==0.0.5) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./learning/notebooks/venv/lib/python3.12/site-packages (from requests->dm-control->playground==0.0.5) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in ./learning/notebooks/venv/lib/python3.12/site-packages (from requests->dm-control->playground==0.0.5) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./learning/notebooks/venv/lib/python3.12/site-packages (from requests->dm-control->playground==0.0.5) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./learning/notebooks/venv/lib/python3.12/site-packages (from requests->dm-control->playground==0.0.5) (2025.8.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in ./learning/notebooks/venv/lib/python3.12/site-packages (from rich>=11.1->flax->playground==0.0.5) (4.0.0)
# Requirement already satisfied: distlib<1,>=0.3.7 in ./learning/notebooks/venv/lib/python3.12/site-packages (from virtualenv>=20.10.0->pre-commit->playground==0.0.5) (0.4.0)
# Requirement already satisfied: filelock<4,>=3.12.2 in ./learning/notebooks/venv/lib/python3.12/site-packages (from virtualenv>=20.10.0->pre-commit->playground==0.0.5) (3.19.1)
# Requirement already satisfied: fsspec in ./learning/notebooks/venv/lib/python3.12/site-packages (from etils[epath]->mujoco>=3.2.7->playground==0.0.5) (2025.9.0)
# Requirement already satisfied: importlib_resources in ./learning/notebooks/venv/lib/python3.12/site-packages (from etils[epath]->mujoco>=3.2.7->playground==0.0.5) (6.5.2)
# Requirement already satisfied: zipp in ./learning/notebooks/venv/lib/python3.12/site-packages (from etils[epath]->mujoco>=3.2.7->playground==0.0.5) (3.23.0)
# Requirement already satisfied: blinker>=1.9.0 in ./learning/notebooks/venv/lib/python3.12/site-packages (from flask->brax>=0.12.1->playground==0.0.5) (1.9.0)
# Requirement already satisfied: itsdangerous>=2.2.0 in ./learning/notebooks/venv/lib/python3.12/site-packages (from flask->brax>=0.12.1->playground==0.0.5) (2.2.0)
# Requirement already satisfied: werkzeug>=3.1.0 in ./learning/notebooks/venv/lib/python3.12/site-packages (from flask->brax>=0.12.1->playground==0.0.5) (3.1.3)
# Requirement already satisfied: comm>=0.1.1 in ./learning/notebooks/venv/lib/python3.12/site-packages (from ipykernel->jupyter->playground==0.0.5) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in ./learning/notebooks/venv/lib/python3.12/site-packages (from ipykernel->jupyter->playground==0.0.5) (1.8.17)
# Requirement already satisfied: jupyter-client>=8.0.0 in ./learning/notebooks/venv/lib/python3.12/site-packages (from ipykernel->jupyter->playground==0.0.5) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in ./learning/notebooks/venv/lib/python3.12/site-packages (from ipykernel->jupyter->playground==0.0.5) (5.8.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in ./learning/notebooks/venv/lib/python3.12/site-packages (from ipykernel->jupyter->playground==0.0.5) (0.1.7)
# Requirement already satisfied: psutil>=5.7 in ./learning/notebooks/venv/lib/python3.12/site-packages (from ipykernel->jupyter->playground==0.0.5) (7.1.0)
# Requirement already satisfied: pyzmq>=25 in ./learning/notebooks/venv/lib/python3.12/site-packages (from ipykernel->jupyter->playground==0.0.5) (27.1.0)
# Requirement already satisfied: tornado>=6.2 in ./learning/notebooks/venv/lib/python3.12/site-packages (from ipykernel->jupyter->playground==0.0.5) (6.5.2)
# Requirement already satisfied: traitlets>=5.4.0 in ./learning/notebooks/venv/lib/python3.12/site-packages (from ipykernel->jupyter->playground==0.0.5) (5.14.3)
# Requirement already satisfied: decorator in ./learning/notebooks/venv/lib/python3.12/site-packages (from ipython->mediapy->playground==0.0.5) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in ./learning/notebooks/venv/lib/python3.12/site-packages (from ipython->mediapy->playground==0.0.5) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in ./learning/notebooks/venv/lib/python3.12/site-packages (from ipython->mediapy->playground==0.0.5) (0.19.2)
# Requirement already satisfied: pexpect>4.3 in ./learning/notebooks/venv/lib/python3.12/site-packages (from ipython->mediapy->playground==0.0.5) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in ./learning/notebooks/venv/lib/python3.12/site-packages (from ipython->mediapy->playground==0.0.5) (3.0.52)
# Requirement already satisfied: stack_data in ./learning/notebooks/venv/lib/python3.12/site-packages (from ipython->mediapy->playground==0.0.5) (0.6.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in ./learning/notebooks/venv/lib/python3.12/site-packages (from ipywidgets->jupyter->playground==0.0.5) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in ./learning/notebooks/venv/lib/python3.12/site-packages (from ipywidgets->jupyter->playground==0.0.5) (3.0.15)
# Requirement already satisfied: async-lru>=1.0.0 in ./learning/notebooks/venv/lib/python3.12/site-packages (from jupyterlab->jupyter->playground==0.0.5) (2.0.5)
# Requirement already satisfied: httpx<1,>=0.25.0 in ./learning/notebooks/venv/lib/python3.12/site-packages (from jupyterlab->jupyter->playground==0.0.5) (0.28.1)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in ./learning/notebooks/venv/lib/python3.12/site-packages (from jupyterlab->jupyter->playground==0.0.5) (2.3.0)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in ./learning/notebooks/venv/lib/python3.12/site-packages (from jupyterlab->jupyter->playground==0.0.5) (2.17.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in ./learning/notebooks/venv/lib/python3.12/site-packages (from jupyterlab->jupyter->playground==0.0.5) (2.27.3)
# Requirement already satisfied: notebook-shim>=0.2 in ./learning/notebooks/venv/lib/python3.12/site-packages (from jupyterlab->jupyter->playground==0.0.5) (0.2.4)
# Requirement already satisfied: beautifulsoup4 in ./learning/notebooks/venv/lib/python3.12/site-packages (from nbconvert->jupyter->playground==0.0.5) (4.14.2)
# Requirement already satisfied: bleach!=5.0.0 in ./learning/notebooks/venv/lib/python3.12/site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter->playground==0.0.5) (6.2.0)
# Requirement already satisfied: defusedxml in ./learning/notebooks/venv/lib/python3.12/site-packages (from nbconvert->jupyter->playground==0.0.5) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in ./learning/notebooks/venv/lib/python3.12/site-packages (from nbconvert->jupyter->playground==0.0.5) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in ./learning/notebooks/venv/lib/python3.12/site-packages (from nbconvert->jupyter->playground==0.0.5) (3.1.4)
# Requirement already satisfied: nbclient>=0.5.0 in ./learning/notebooks/venv/lib/python3.12/site-packages (from nbconvert->jupyter->playground==0.0.5) (0.10.2)
# Requirement already satisfied: nbformat>=5.7 in ./learning/notebooks/venv/lib/python3.12/site-packages (from nbconvert->jupyter->playground==0.0.5) (5.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in ./learning/notebooks/venv/lib/python3.12/site-packages (from nbconvert->jupyter->playground==0.0.5) (1.5.1)
# Requirement already satisfied: chex>=0.1.87 in ./learning/notebooks/venv/lib/python3.12/site-packages (from optax->brax>=0.12.1->playground==0.0.5) (0.1.91)
# Requirement already satisfied: webencodings in ./learning/notebooks/venv/lib/python3.12/site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->jupyter->playground==0.0.5) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in ./learning/notebooks/venv/lib/python3.12/site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter->playground==0.0.5) (1.4.0)
# Requirement already satisfied: toolz>=1.0.0 in ./learning/notebooks/venv/lib/python3.12/site-packages (from chex>=0.1.87->optax->brax>=0.12.1->playground==0.0.5) (1.0.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in ./learning/notebooks/venv/lib/python3.12/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb->playground==0.0.5) (5.0.2)
# Requirement already satisfied: anyio in ./learning/notebooks/venv/lib/python3.12/site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter->playground==0.0.5) (4.11.0)
# Requirement already satisfied: httpcore==1.* in ./learning/notebooks/venv/lib/python3.12/site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter->playground==0.0.5) (1.0.9)
# Requirement already satisfied: h11>=0.16 in ./learning/notebooks/venv/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab->jupyter->playground==0.0.5) (0.16.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in ./learning/notebooks/venv/lib/python3.12/site-packages (from jedi>=0.16->ipython->mediapy->playground==0.0.5) (0.8.5)
# Requirement already satisfied: argon2-cffi>=21.1 in ./learning/notebooks/venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->playground==0.0.5) (25.1.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in ./learning/notebooks/venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->playground==0.0.5) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in ./learning/notebooks/venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->playground==0.0.5) (0.5.3)
# Requirement already satisfied: prometheus-client>=0.9 in ./learning/notebooks/venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->playground==0.0.5) (0.23.1)
# Requirement already satisfied: send2trash>=1.8.2 in ./learning/notebooks/venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->playground==0.0.5) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in ./learning/notebooks/venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->playground==0.0.5) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in ./learning/notebooks/venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->playground==0.0.5) (1.8.0)
# Requirement already satisfied: babel>=2.10 in ./learning/notebooks/venv/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->playground==0.0.5) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in ./learning/notebooks/venv/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->playground==0.0.5) (0.12.1)
# Requirement already satisfied: jsonschema>=4.18.0 in ./learning/notebooks/venv/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->playground==0.0.5) (4.25.1)
# Requirement already satisfied: mdurl~=0.1 in ./learning/notebooks/venv/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=11.1->flax->playground==0.0.5) (0.1.2)
# Requirement already satisfied: fastjsonschema>=2.15 in ./learning/notebooks/venv/lib/python3.12/site-packages (from nbformat>=5.7->nbconvert->jupyter->playground==0.0.5) (2.21.2)
# Requirement already satisfied: ptyprocess>=0.5 in ./learning/notebooks/venv/lib/python3.12/site-packages (from pexpect>4.3->ipython->mediapy->playground==0.0.5) (0.7.0)
# Requirement already satisfied: wcwidth in ./learning/notebooks/venv/lib/python3.12/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython->mediapy->playground==0.0.5) (0.2.14)
# Requirement already satisfied: soupsieve>1.2 in ./learning/notebooks/venv/lib/python3.12/site-packages (from beautifulsoup4->nbconvert->jupyter->playground==0.0.5) (2.8)
# Requirement already satisfied: executing>=1.2.0 in ./learning/notebooks/venv/lib/python3.12/site-packages (from stack_data->ipython->mediapy->playground==0.0.5) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in ./learning/notebooks/venv/lib/python3.12/site-packages (from stack_data->ipython->mediapy->playground==0.0.5) (3.0.0)
# Requirement already satisfied: pure-eval in ./learning/notebooks/venv/lib/python3.12/site-packages (from stack_data->ipython->mediapy->playground==0.0.5) (0.2.3)
# Requirement already satisfied: sniffio>=1.1 in ./learning/notebooks/venv/lib/python3.12/site-packages (from anyio->httpx<1,>=0.25.0->jupyterlab->jupyter->playground==0.0.5) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in ./learning/notebooks/venv/lib/python3.12/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->playground==0.0.5) (25.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in ./learning/notebooks/venv/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->playground==0.0.5) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in ./learning/notebooks/venv/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->playground==0.0.5) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in ./learning/notebooks/venv/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->playground==0.0.5) (0.27.1)
# Requirement already satisfied: python-json-logger>=2.0.4 in ./learning/notebooks/venv/lib/python3.12/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->playground==0.0.5) (3.3.0)
# Requirement already satisfied: rfc3339-validator in ./learning/notebooks/venv/lib/python3.12/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->playground==0.0.5) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in ./learning/notebooks/venv/lib/python3.12/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->playground==0.0.5) (0.1.1)
# Requirement already satisfied: fqdn in ./learning/notebooks/venv/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->playground==0.0.5) (1.5.1)
# Requirement already satisfied: isoduration in ./learning/notebooks/venv/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->playground==0.0.5) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in ./learning/notebooks/venv/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->playground==0.0.5) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in ./learning/notebooks/venv/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->playground==0.0.5) (1.1.0)
# Requirement already satisfied: uri-template in ./learning/notebooks/venv/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->playground==0.0.5) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in ./learning/notebooks/venv/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->playground==0.0.5) (24.11.1)
# Requirement already satisfied: cffi>=1.0.1 in ./learning/notebooks/venv/lib/python3.12/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->playground==0.0.5) (2.0.0)
# Requirement already satisfied: pycparser in ./learning/notebooks/venv/lib/python3.12/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->playground==0.0.5) (2.23)
# Requirement already satisfied: lark>=1.2.2 in ./learning/notebooks/venv/lib/python3.12/site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->playground==0.0.5) (1.3.0)
# Requirement already satisfied: arrow>=0.15.0 in ./learning/notebooks/venv/lib/python3.12/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->playground==0.0.5) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in ./learning/notebooks/venv/lib/python3.12/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->playground==0.0.5) (2.9.0.20250822)
# Building wheels for collected packages: playground
#   Building editable for playground (pyproject.toml) ... done
#   Created wheel for playground: filename=playground-0.0.5-py3-none-any.whl size=8241 sha256=b99f04ef59686acfd3454d4ddad283cf5ed68628a8f26592cdcc7609134aa5e3
#   Stored in directory: /tmp/pip-ephem-wheel-cache-9s3m2sqe/wheels/48/ed/7d/2e35d3caaa09cd96e2e431782a1e6ef26184198ad4ad1e18d0
# Successfully built playground
# Installing collected packages: playground
#   Attempting uninstall: playground
#     Found existing installation: playground 0.0.5
#     Uninstalling playground-0.0.5:
#       Successfully uninstalled playground-0.0.5
# Successfully installed playground-0.0.5
#
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip
# Collecting jax[cuda12]
#   Using cached jax-0.7.2-py3-none-any.whl.metadata (13 kB)
# Collecting jaxlib<=0.7.2,>=0.7.2 (from jax[cuda12])
#   Using cached jaxlib-0.7.2-cp312-cp312-manylinux_2_27_x86_64.whl.metadata (1.3 kB)
# Collecting ml_dtypes>=0.5.0 (from jax[cuda12])
#   Using cached ml_dtypes-0.5.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.9 kB)
# Collecting numpy>=2.0 (from jax[cuda12])
#   Using cached numpy-2.3.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (62 kB)
# Collecting opt_einsum (from jax[cuda12])
#   Using cached opt_einsum-3.4.0-py3-none-any.whl.metadata (6.3 kB)
# Collecting scipy>=1.13 (from jax[cuda12])
#   Using cached scipy-1.16.2-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (62 kB)
# Collecting jax-cuda12-plugin<=0.7.2,>=0.7.2 (from jax-cuda12-plugin[with-cuda]<=0.7.2,>=0.7.2; extra == "cuda12"->jax[cuda12])
#   Using cached jax_cuda12_plugin-0.7.2-cp312-cp312-manylinux_2_27_x86_64.whl.metadata (2.0 kB)
# Collecting jax-cuda12-pjrt==0.7.2 (from jax-cuda12-plugin<=0.7.2,>=0.7.2->jax-cuda12-plugin[with-cuda]<=0.7.2,>=0.7.2; extra == "cuda12"->jax[cuda12])
#   Using cached jax_cuda12_pjrt-0.7.2-py3-none-manylinux_2_27_x86_64.whl.metadata (579 bytes)
# Collecting nvidia-cublas-cu12>=12.1.3.1 (from jax-cuda12-plugin[with-cuda]<=0.7.2,>=0.7.2; extra == "cuda12"->jax[cuda12])
#   Using cached nvidia_cublas_cu12-12.9.1.4-py3-none-manylinux_2_27_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cuda-cupti-cu12>=12.1.105 (from jax-cuda12-plugin[with-cuda]<=0.7.2,>=0.7.2; extra == "cuda12"->jax[cuda12])
#   Using cached nvidia_cuda_cupti_cu12-12.9.79-py3-none-manylinux_2_25_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-cuda-nvcc-cu12>=12.6.85 (from jax-cuda12-plugin[with-cuda]<=0.7.2,>=0.7.2; extra == "cuda12"->jax[cuda12])
#   Using cached nvidia_cuda_nvcc_cu12-12.9.86-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cuda-runtime-cu12>=12.1.105 (from jax-cuda12-plugin[with-cuda]<=0.7.2,>=0.7.2; extra == "cuda12"->jax[cuda12])
#   Using cached nvidia_cuda_runtime_cu12-12.9.79-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cudnn-cu12<10.0,>=9.8 (from jax-cuda12-plugin[with-cuda]<=0.7.2,>=0.7.2; extra == "cuda12"->jax[cuda12])
#   Using cached nvidia_cudnn_cu12-9.13.1.26-py3-none-manylinux_2_27_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-cufft-cu12>=11.0.2.54 (from jax-cuda12-plugin[with-cuda]<=0.7.2,>=0.7.2; extra == "cuda12"->jax[cuda12])
#   Using cached nvidia_cufft_cu12-11.4.1.4-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-cusolver-cu12>=11.4.5.107 (from jax-cuda12-plugin[with-cuda]<=0.7.2,>=0.7.2; extra == "cuda12"->jax[cuda12])
#   Using cached nvidia_cusolver_cu12-11.7.5.82-py3-none-manylinux_2_27_x86_64.whl.metadata (1.9 kB)
# Collecting nvidia-cusparse-cu12>=12.1.0.106 (from jax-cuda12-plugin[with-cuda]<=0.7.2,>=0.7.2; extra == "cuda12"->jax[cuda12])
#   Using cached nvidia_cusparse_cu12-12.5.10.65-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nccl-cu12>=2.18.1 (from jax-cuda12-plugin[with-cuda]<=0.7.2,>=0.7.2; extra == "cuda12"->jax[cuda12])
#   Using cached nvidia_nccl_cu12-2.28.3-py3-none-manylinux_2_18_x86_64.whl.metadata (2.0 kB)
# Collecting nvidia-nvjitlink-cu12>=12.1.105 (from jax-cuda12-plugin[with-cuda]<=0.7.2,>=0.7.2; extra == "cuda12"->jax[cuda12])
#   Using cached nvidia_nvjitlink_cu12-12.9.86-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cuda-nvrtc-cu12>=12.1.55 (from jax-cuda12-plugin[with-cuda]<=0.7.2,>=0.7.2; extra == "cuda12"->jax[cuda12])
#   Using cached nvidia_cuda_nvrtc_cu12-12.9.86-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-nvshmem-cu12>=3.2.5 (from jax-cuda12-plugin[with-cuda]<=0.7.2,>=0.7.2; extra == "cuda12"->jax[cuda12])
#   Using cached nvidia_nvshmem_cu12-3.4.5-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.1 kB)
# Using cached jax_cuda12_plugin-0.7.2-cp312-cp312-manylinux_2_27_x86_64.whl (5.5 MB)
# Using cached jax_cuda12_pjrt-0.7.2-py3-none-manylinux_2_27_x86_64.whl (132.7 MB)
# Using cached jaxlib-0.7.2-cp312-cp312-manylinux_2_27_x86_64.whl (78.2 MB)
# Using cached ml_dtypes-0.5.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (4.9 MB)
# Using cached numpy-2.3.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.6 MB)
# Using cached scipy-1.16.2-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (35.7 MB)
# Using cached jax-0.7.2-py3-none-any.whl (2.8 MB)
# Using cached opt_einsum-3.4.0-py3-none-any.whl (71 kB)
# Using cached nvidia_cublas_cu12-12.9.1.4-py3-none-manylinux_2_27_x86_64.whl (581.2 MB)
# Using cached nvidia_cuda_cupti_cu12-12.9.79-py3-none-manylinux_2_25_x86_64.whl (10.8 MB)
# Using cached nvidia_cuda_nvcc_cu12-12.9.86-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (40.5 MB)
# Using cached nvidia_cuda_nvrtc_cu12-12.9.86-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (89.6 MB)
# Using cached nvidia_cuda_runtime_cu12-12.9.79-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.5 MB)
# Using cached nvidia_cudnn_cu12-9.13.1.26-py3-none-manylinux_2_27_x86_64.whl (644.3 MB)
# Using cached nvidia_cufft_cu12-11.4.1.4-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (200.9 MB)
# Using cached nvidia_cusolver_cu12-11.7.5.82-py3-none-manylinux_2_27_x86_64.whl (338.1 MB)
# Using cached nvidia_cusparse_cu12-12.5.10.65-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (366.5 MB)
# Using cached nvidia_nccl_cu12-2.28.3-py3-none-manylinux_2_18_x86_64.whl (295.9 MB)
# Using cached nvidia_nvjitlink_cu12-12.9.86-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (39.7 MB)
# Using cached nvidia_nvshmem_cu12-3.4.5-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (139.1 MB)
# Installing collected packages: jax-cuda12-pjrt, opt_einsum, nvidia-nvshmem-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-nvcc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, numpy, jax-cuda12-plugin, scipy, nvidia-cusparse-cu12, nvidia-cufft-cu12, nvidia-cudnn-cu12, ml_dtypes, nvidia-cusolver-cu12, jaxlib, jax
#   Attempting uninstall: jax-cuda12-pjrt
#     Found existing installation: jax-cuda12-pjrt 0.7.2
#     Uninstalling jax-cuda12-pjrt-0.7.2:
#       Successfully uninstalled jax-cuda12-pjrt-0.7.2
#   Attempting uninstall: opt_einsum
#     Found existing installation: opt_einsum 3.4.0
#     Uninstalling opt_einsum-3.4.0:
#       Successfully uninstalled opt_einsum-3.4.0
#   Attempting uninstall: nvidia-nvshmem-cu12
#     Found existing installation: nvidia-nvshmem-cu12 3.4.5
#     Uninstalling nvidia-nvshmem-cu12-3.4.5:
#       Successfully uninstalled nvidia-nvshmem-cu12-3.4.5
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.9.86
#     Uninstalling nvidia-nvjitlink-cu12-12.9.86:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.9.86
#   Attempting uninstall: nvidia-nccl-cu12
#     Found existing installation: nvidia-nccl-cu12 2.28.3
#     Uninstalling nvidia-nccl-cu12-2.28.3:
#       Successfully uninstalled nvidia-nccl-cu12-2.28.3
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.9.79
#     Uninstalling nvidia-cuda-runtime-cu12-12.9.79:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.9.79
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.9.86
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.9.86:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.9.86
#   Attempting uninstall: nvidia-cuda-nvcc-cu12
#     Found existing installation: nvidia-cuda-nvcc-cu12 12.9.86
#     Uninstalling nvidia-cuda-nvcc-cu12-12.9.86:
#       Successfully uninstalled nvidia-cuda-nvcc-cu12-12.9.86
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.9.79
#     Uninstalling nvidia-cuda-cupti-cu12-12.9.79:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.9.79
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.9.1.4
#     Uninstalling nvidia-cublas-cu12-12.9.1.4:
#       Successfully uninstalled nvidia-cublas-cu12-12.9.1.4
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.3.3
#     Uninstalling numpy-2.3.3:
#       Successfully uninstalled numpy-2.3.3
#   Attempting uninstall: jax-cuda12-plugin
#     Found existing installation: jax-cuda12-plugin 0.7.2
#     Uninstalling jax-cuda12-plugin-0.7.2:
#       Successfully uninstalled jax-cuda12-plugin-0.7.2
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.16.2
#     Uninstalling scipy-1.16.2:
#       Successfully uninstalled scipy-1.16.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.10.65
#     Uninstalling nvidia-cusparse-cu12-12.5.10.65:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.10.65
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.4.1.4
#     Uninstalling nvidia-cufft-cu12-11.4.1.4:
#       Successfully uninstalled nvidia-cufft-cu12-11.4.1.4
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.13.1.26
#     Uninstalling nvidia-cudnn-cu12-9.13.1.26:
#       Successfully uninstalled nvidia-cudnn-cu12-9.13.1.26
#   Attempting uninstall: ml_dtypes
#     Found existing installation: ml_dtypes 0.5.3
#     Uninstalling ml_dtypes-0.5.3:
#       Successfully uninstalled ml_dtypes-0.5.3
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.7.5.82
#     Uninstalling nvidia-cusolver-cu12-11.7.5.82:
#       Successfully uninstalled nvidia-cusolver-cu12-11.7.5.82
#   Attempting uninstall: jaxlib
#     Found existing installation: jaxlib 0.7.2
#     Uninstalling jaxlib-0.7.2:
#       Successfully uninstalled jaxlib-0.7.2
#   Attempting uninstall: jax
#     Found existing installation: jax 0.7.2
#     Uninstalling jax-0.7.2:
#       Successfully uninstalled jax-0.7.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tf2onnx 1.16.1 requires protobuf~=3.20, but you have protobuf 6.32.1 which is incompatible.
# Successfully installed jax-0.7.2 jax-cuda12-pjrt-0.7.2 jax-cuda12-plugin-0.7.2 jaxlib-0.7.2 ml_dtypes-0.5.3 numpy-2.3.3 nvidia-cublas-cu12-12.9.1.4 nvidia-cuda-cupti-cu12-12.9.79 nvidia-cuda-nvcc-cu12-12.9.86 nvidia-cuda-nvrtc-cu12-12.9.86 nvidia-cuda-runtime-cu12-12.9.79 nvidia-cudnn-cu12-9.13.1.26 nvidia-cufft-cu12-11.4.1.4 nvidia-cusolver-cu12-11.7.5.82 nvidia-cusparse-cu12-12.5.10.65 nvidia-nccl-cu12-2.28.3 nvidia-nvjitlink-cu12-12.9.86 nvidia-nvshmem-cu12-3.4.5 opt_einsum-3.4.0 scipy-1.16.2
#
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip

# %%
import jax
import jaxlib

print(f"JAX version: {jax.__version__}")
print(f"jaxlib version: {jaxlib.__version__}")

if jax.__version__ not in ["0.7.1", "0.7.2"]:
  # !pip install --upgrade --force-reinstall "jax[cuda12]"
# Out:
# JAX version: 0.7.2
# jaxlib version: 0.7.2

# %%
# from google.colab import drive
# drive.mount("/content/drive")

# # Allow execution in Google Drive if neccesary
# %cd /content/drive/MyDrive/mujoco_pg_env/bin
# !chmod +x *

# %%
# !source /content/drive/MyDrive/mujoco_pg_env/bin/activate && cd /content/drive/MyDrive/HACHIX-project/mujoco_playground/ && pip install -e ".[all]"

# %%
# !source /content/drive/MyDrive/mujoco_pg_env/bin/activate && pip install playground

# %%
# !source /home/sandbox/Work/mujoco_playground/learning/notebooks/venv/bin/activate

# %%
# %env MUJOCO_GL=egl
# Out:
# env: MUJOCO_GL=egl

# %%
import sys
sys.path.append("/home/sandbox/Work/mujoco_playground/learning/notebooks/venv/lib/python3.12/site-packages")
sys.path.append("/home/sandbox/Work/mujoco_playground")
sys.path
# Out:
# ['',
#  '/opt/ros/humble/lib/python3.10/site-packages',
#  '/opt/ros/humble/local/lib/python3.10/dist-packages',
#  '/usr/lib/python312.zip',
#  '/usr/lib/python3.12',
#  '/usr/lib/python3.12/lib-dynload',
#  '/home/sandbox/Work/mujoco_playground/learning/notebooks/venv/lib/python3.12/site-packages',
#  '/home/sandbox/Work/mujoco_playground',
#  '/home/sandbox/Work/mujoco_playground/learning/notebooks/venv/lib/python3.12/site-packages',
#  '/home/sandbox/Work/mujoco_playground']

# %%
# @title Import packages for plotting and creating graphics
import json
import itertools
import time
from typing import Callable, List, NamedTuple, Optional, Union
import numpy as np

# Graphics and plotting.
# print("Installing mediapy:")
# !command -v ffmpeg >/dev/null || (apt update && apt install -y ffmpeg)
# !pip install -q mediapy
import mediapy as media
import matplotlib.pyplot as plt

# More legible printing from numpy.
np.set_printoptions(precision=3, suppress=True, linewidth=100)

# %%
# @title Import MuJoCo, MJX, and Brax
# !pip install numpy --upgrade
from datetime import datetime
import functools
import os
from typing import Any, Dict, Sequence, Tuple, Union
from brax import base
from brax import envs
from brax import math
from brax.base import Base, Motion, Transform
from brax.base import State as PipelineState
from brax.envs.base import Env, PipelineEnv, State
from brax.io import html, mjcf, model
from brax.mjx.base import State as MjxState
from brax.training.agents.ppo import networks as ppo_networks
from brax.training.agents.ppo import train as ppo
from brax.training.agents.sac import networks as sac_networks
from brax.training.agents.sac import train as sac
from etils import epath
from flax import struct
from flax.training import orbax_utils
from IPython.display import HTML, clear_output
import jax
from jax import numpy as jp
from matplotlib import pyplot as plt
import mediapy as media
from ml_collections import config_dict
import mujoco
from mujoco import mjx
import numpy as np
from orbax import checkpoint as ocp
# Out:
# Requirement already satisfied: numpy in ./venv/lib/python3.12/site-packages (2.3.3)
#
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip
# Failed to import warp: No module named 'warp'
# Failed to import mujoco.mjx.third_party.mujoco_warp as mujoco_warp: No module named 'warp'

# %%
  #@title Import The Playground

from mujoco_playground import wrapper
from mujoco_playground import registry
from etils import epath
from mujoco_playground._src import mjx_env
import mujoco.viewer

# %%
from mujoco_playground.config import locomotion_params

# %%
env_name = 'HunterJoystick'
_PLAY_ONLY = False
# _LOAD_CHECKPOINT_PATH = "/content/drive/MyDrive/HACHIX-project/mujoco_playground/logs/HunterJoystick-20250913-131738/checkpoints"
_LOAD_CHECKPOINT_PATH = "/content/drive/MyDrive/HACHIX-project/mujoco_playground/logs/HunterJoystick-20250913-151258/checkpoints"

#3rd Reduced obs
_LOAD_CHECKPOINT_PATH = "/content/drive/MyDrive/HACHIX-project/mujoco_playground/logs/HunterJoystick-20250919-005307/checkpoints" #200k steps
_LOAD_CHECKPOINT_PATH = "/content/drive/MyDrive/HACHIX-project/mujoco_playground/logs/HunterJoystick-20250919-022259/checkpoints" # 1mils200k steps
_LOAD_CHECKPOINT_PATH = "/content/drive/MyDrive/HACHIX-project/mujoco_playground/logs/HunterJoystick-20250919-074629/checkpoints"
_LOAD_CHECKPOINT_PATH = "/content/drive/MyDrive/HACHIX-project/mujoco_playground/logs/HunterJoystick-20250919-091701/checkpoints"
_LOAD_CHECKPOINT_PATH = "/content/drive/MyDrive/HACHIX-project/mujoco_playground/logs/HunterJoystick-20250919-105650/checkpoints"
_LOAD_CHECKPOINT_PATH = "/content/drive/MyDrive/HACHIX-project/mujoco_playground/logs/HunterJoystick-20250919-140651/checkpoints"
_LOAD_CHECKPOINT_PATH = "/content/drive/MyDrive/HACHIX-project/mujoco_playground/logs/HunterJoystick-20250919-154753/checkpoints" ## Current best

#Fix kp kd
_LOAD_CHECKPOINT_PATH = "/content/drive/MyDrive/HACHIX-project/mujoco_playground/logs/HunterJoystick-20250928-143848/checkpoints"
_LOAD_CHECKPOINT_PATH = "/content/drive/MyDrive/HACHIX-project/mujoco_playground/logs/HunterJoystick-20250928-164017/checkpoints"
_LOAD_CHECKPOINT_PATH = "/content/drive/MyDrive/HACHIX-project/mujoco_playground/logs/HunterJoystick-20250929-030300/checkpoints"

#Fix forceRange
_LOAD_CHECKPOINT_PATH = "/content/drive/MyDrive/HACHIX-project/mujoco_playground/logs/HunterJoystick-20250929-091157/checkpoints"
_LOAD_CHECKPOINT_PATH = "/content/drive/MyDrive/HACHIX-project/mujoco_playground/logs/HunterJoystick-20250929-133124/checkpoints"

#Add noises
_LOAD_CHECKPOINT_PATH = "/content/drive/MyDrive/HACHIX-project/mujoco_playground/logs/HunterJoystick-20250930-041904/checkpoints"
_LOAD_CHECKPOINT_PATH = "/content/drive/MyDrive/HACHIX-project/mujoco_playground/logs/HunterJoystick-20250930-150416/checkpoints"
_LOAD_CHECKPOINT_PATH = "/content/drive/MyDrive/HACHIX-project/mujoco_playground/logs/HunterJoystick-20251001-020621/checkpoints"

_LOAD_CHECKPOINT_PATH = None

env = registry.load(env_name)
env_cfg = registry.get_default_config(env_name)
ppo_params = locomotion_params.brax_ppo_config(env_name)

# %%
env_cfg
# Out:
# action_repeat: 1
# action_scale: 0.5
# command_config:
#   ang_vel_threshold: 0.1
#   ang_vel_yaw:
#   - -0.0
#   - 0.0
#   lin_vel_threshold: 0.1
#   lin_vel_x:
#   - -0.0
#   - 0.0
#   lin_vel_y:
#   - -0.0
#   - 0.0
# ctrl_dt: 0.02
# dof_vel_scale: 0.05
# early_termination: true
# episode_length: 1000
# foot_height:
# - 0.15
# - 0.6
# gait_frequency:
# - 0.0
# - 0.5
# gaits:
# - walk
# - stand
# history_len: 1
# impl: jax
# nconmax: 8192
# njmax: 42
# obs_noise:
#   level: 0.6
#   scales:
#     gravity: 0.05
#     gyro: 0.2
#     joint_pos: 0.01
#     joint_vel: 1.5
# push_config:
#   enable: true
#   interval_range:
#   - 5.0
#   - 10.0
#   magnitude_range:
#   - 0.1
#   - 1.0
# reward_config:
#   scales:
#     action_rate: -0.01
#     ang_vel_xy: -0.0
#     feet_air_time: 2.0
#     feet_clearance: -1.0
#     feet_contact: 0.5
#     feet_distance: -0.3
#     feet_phase: 3.0
#     foot_slip: -0.1
#     lin_vel_z: -5.0
#     orientation: -2.0
#     pose: -1.0
#     stand_still: 4.0
#     tracking_ang_vel: 0.75
#     tracking_lin_vel: 3.5
#   tracking_sigma: 0.5
# sim_dt: 0.002

# %%
## For inference
if _PLAY_ONLY:
    ppo_params["num_timesteps"] = 0
else:
    ppo_params["num_timesteps"]= 100000000
    # ppo_params["num_timesteps"]= 20000000

# %%
  ppo_params
# Out:
# action_repeat: 1
# batch_size: 256
# discounting: 0.97
# entropy_cost: 0.01
# episode_length: 1000
# learning_rate: 0.0003
# max_grad_norm: 1.0
# network_factory:
#   policy_hidden_layer_sizes: !!python/tuple
#   - 128
#   - 128
#   - 128
#   - 128
#   policy_obs_key: state
#   value_hidden_layer_sizes: !!python/tuple
#   - 256
#   - 256
#   - 256
#   - 256
#   - 256
#   value_obs_key: state
# normalize_observations: true
# num_envs: 4096
# num_evals: 10
# num_minibatches: 32
# num_timesteps: 100000000
# num_updates_per_batch: 4
# reward_scaling: 1.0
# unroll_length: 20

# %%
x_data, y_data, y_dataerr = [], [], []
times = [datetime.now()]

def progress(num_steps, metrics):
  clear_output(wait=True)

  times.append(datetime.now())
  x_data.append(num_steps)
  y_data.append(metrics["eval/episode_reward"])
  y_dataerr.append(metrics["eval/episode_reward_std"])

  plt.xlim([0, ppo_params["num_timesteps"] * 1.25])
  plt.xlabel("# environment steps")
  plt.ylabel("reward per episode")
  plt.title(f"y={y_data[-1]:.3f}")
  plt.errorbar(x_data, y_data, yerr=y_dataerr, color="blue")

  display(plt.gcf())

randomizer = registry.get_domain_randomizer(env_name)
ppo_training_params = dict(ppo_params)
network_factory = ppo_networks.make_ppo_networks
if "network_factory" in ppo_params:
  del ppo_training_params["network_factory"]
  network_factory = functools.partial(
      ppo_networks.make_ppo_networks,
      **ppo_params.network_factory
  )

# Handle checkpoint loading
if _LOAD_CHECKPOINT_PATH is not None:
    # Convert to absolute path
    ckpt_path = epath.Path(_LOAD_CHECKPOINT_PATH).resolve()
    if ckpt_path.is_dir():
      latest_ckpts = list(ckpt_path.glob("*"))
      latest_ckpts = [ckpt for ckpt in latest_ckpts if ckpt.is_dir()]
      latest_ckpts.sort(key=lambda x: int(x.name))
      latest_ckpt = latest_ckpts[-1]
      restore_checkpoint_path = latest_ckpt
      print(f"Restoring from: {restore_checkpoint_path}")
    else:
      restore_checkpoint_path = ckpt_path
      print(f"Restoring from checkpoint: {restore_checkpoint_path}")
else:
    print("No checkpoint path provided, not restoring from checkpoint")
    restore_checkpoint_path = None

if not _PLAY_ONLY:
    # Generate unique experiment name
    now = datetime.now()
    timestamp = now.strftime("%Y%m%d-%H%M%S")
    exp_name = f"{env_name}-{timestamp}"
    print(f"Experiment name: {exp_name}")

    # Set up logging directory
    logdir = epath.Path("/home/sandbox/Work/mujoco_playground/learning/notebooks/logs/").resolve() / exp_name
    logdir.mkdir(parents=True, exist_ok=True)
    print(f"Logs are being stored in: {logdir}")

    # Set up checkpoint directory
    ckpt_path = logdir / "checkpoints"
    ckpt_path.mkdir(parents=True, exist_ok=True)
    print(f"Checkpoint path: {ckpt_path}")

    with open(ckpt_path / "config.json", "w", encoding="utf-8") as fp:
      json.dump(env_cfg.to_dict(), fp, indent=4)
else:
    ckpt_path = None

train_fn = functools.partial(
    ppo.train, **dict(ppo_training_params),
    network_factory=network_factory,
    save_checkpoint_path=ckpt_path,
    restore_checkpoint_path=restore_checkpoint_path,
    randomization_fn=randomizer,
    progress_fn=progress
)
# Out:
# Env 'HunterJoystick' does not have a domain randomizer in the locomotion registry.
# No checkpoint path provided, not restoring from checkpoint
# Experiment name: HunterJoystick-20251004-001043
# Logs are being stored in: /home/sandbox/Work/mujoco_playground/learning/notebooks/logs/HunterJoystick-20251004-001043
# Checkpoint path: /home/sandbox/Work/mujoco_playground/learning/notebooks/logs/HunterJoystick-20251004-001043/checkpoints

# %%
make_inference_fn, params, metrics = train_fn(
    environment=env,
    eval_env=registry.load(env_name, config=env_cfg),
    wrap_env_fn=wrapper.wrap_for_brax_training,
)
if len(times) > 1:
    print(f"time to jit: {times[1] - times[0]}")
    print(f"time to train: {times[-1] - times[1]}")

# %%
#@title Rollout and Render
from mujoco_playground._src.gait import draw_joystick_command
import mujoco

env = registry.load(env_name)
eval_env = registry.load(env_name)
jit_reset = jax.jit(eval_env.reset)
jit_step = jax.jit(eval_env.step)
jit_inference_fn = jax.jit(make_inference_fn(params, deterministic=True))

rng = jax.random.PRNGKey(1)

rollout = []
modify_scene_fns = []

phase_dt = 2 * 0.5* jp.pi * eval_env.dt * 1.5
phase = jp.array([0, jp.pi])
# phase = jp.array([0, 0.0])


log_push = []

push_step = 150  # When to apply the push
push_force_x = jp.array([-10.0, 0.0, 0.0])  # Newtons in -X direction
push_force_y = jp.array([0.0, 0.0, 0.0])  # Newtons in +Y direction
push_duration = 10  # How many steps the push lasts

body_id = eval_env.mj_model.body("base_link").id

def draw_force_arrow(scene: mujoco.MjvScene, data: mujoco.MjData):
    body_pos = data.xpos[body_id]
    applied_force = np.array(data.xfrc_applied[body_id][:3])

    force_magnitude = np.linalg.norm(applied_force)
    if force_magnitude < 1e-3:
        return

    # Visualization scale: adjust this value to your preference
    visualization_scale = 0.01
    arrow_length = force_magnitude * visualization_scale

    # Direction of the force
    arrow_dir = applied_force / force_magnitude

    # Orientation matrix (Z axis → arrow_dir)
    z_axis = np.array([0, 0, 1])
    if np.allclose(arrow_dir, z_axis) or np.allclose(arrow_dir, -z_axis):
        rot_mat = np.eye(3)
    else:
        v = np.cross(z_axis, arrow_dir)
        s = np.linalg.norm(v)
        c = np.dot(z_axis, arrow_dir)
        vx = np.array([
            [0, -v[2], v[1]],
            [v[2], 0, -v[0]],
            [-v[1], v[0], 0]
        ])
        rot_mat = np.eye(3) + vx + vx @ vx * ((1 - c) / (s**2 + 1e-8))

    geom_id = scene.ngeom
    if geom_id >= len(scene.geoms):
        return

    # Create a new geom object and add it to the scene
    geom = scene.geoms[geom_id]

    # Arrow geom type
    geom.type = mujoco.mjtGeom.mjGEOM_ARROW

    # Set the geom size: [shaft_radius, head_radius, arrow_length]
    geom.size[:] = [0.01, 0.02, arrow_length]

    # Position the geom at the body and orient it
    geom.pos[:] = body_pos
    geom.mat[:] = rot_mat

    geom.rgba[:] = [1, 0, 0, 1]
    scene.ngeom += 1

# # Log eval action to csv
# joint_names = []
# for i in range(env._mj_model.nu):
#   name = mujoco.mj_id2name(env._mj_model, mujoco.mjtObj.mjOBJ_ACTUATOR, i)
#   print(i, name)
#   joint_names.append(name)
# csv_header = ["steps"] + joint_names

for j in range(1):
  print(f"episode {j}")
  state = jit_reset(rng)
  state.info["phase_dt"] = phase_dt
  state.info["phase"] = phase

  # with open("actions_log.csv", mode="w", newline="") as file:
  #   writer = csv.writer(file)
  #   writer.writerow(csv_header)
  step = 0

  for i in range(env_cfg.episode_length):
      act_rng, rng = jax.random.split(rng)
      ctrl, _ = jit_inference_fn(state.obs, act_rng)
      print(state.obs)

      data = state.data
      if push_step <= i < push_step + push_duration:
          # Create a force vector (6D: force + torque)
          force = jp.concatenate([push_force_x, jp.zeros(3)])  # No torque
          data = data.replace(
              xfrc_applied=data.xfrc_applied.at[body_id].set(force)
          )
      elif push_step*2 <= i < push_step*2 + push_duration:
          # Create a force vector (6D: force + torque)
          force = jp.concatenate([push_force_y, jp.zeros(3)])  # No torque
          data = data.replace(
              xfrc_applied=data.xfrc_applied.at[body_id].set(force)
          )
      else:
          # No force
          data = data.replace(
              xfrc_applied=data.xfrc_applied.at[body_id].set(jp.zeros(6))
          )

      state = state.replace(data=data)

      state = jit_step(state, ctrl)
      # if state.done:
      #   break
      # state.info["command"] = command
      rollout.append(state)
      step += 1

      # Log step + action values
      # writer.writerow([step] + list(ctrl))

      modify_scene_fns.append(
          functools.partial(
              draw_force_arrow,
              data=state.data
          )
      )


render_every = 1
fps = 1.0 / eval_env.dt / render_every
print(f"fps: {fps}")
traj = rollout[::render_every]
mod_fns = modify_scene_fns[::render_every]

scene_option = mujoco.MjvOption()
scene_option.geomgroup[2] = True
scene_option.geomgroup[3] = False
scene_option.flags[mujoco.mjtVisFlag.mjVIS_CONTACTPOINT] = True
scene_option.flags[mujoco.mjtVisFlag.mjVIS_TRANSPARENT] = False
scene_option.flags[mujoco.mjtVisFlag.mjVIS_PERTFORCE] = False
frames = eval_env.render(
    traj,
    camera="track",
    scene_option=scene_option,
    width=640,
    height=480,
    modify_scene_fns=mod_fns,
)
media.show_video(frames, fps=fps, loop=False)
media.write_video("/content/drive/MyDrive/HACHIX-project/videos/colab10_5_hunter_stand_X-10N_Y+10N_noise0.8_output.mp4", frames, fps=fps, qp=18)
